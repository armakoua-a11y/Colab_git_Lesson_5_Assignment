# %% [markdown]
# <a href="https://colab.research.google.com/github/armakoua-a11y/Colab_git_Lesson_5_Assignment/blob/main/Assignment_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Assignment 8: Supervised Learning Classification
